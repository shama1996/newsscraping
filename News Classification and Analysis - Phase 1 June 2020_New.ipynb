# %%
#importing all the required libraries
import selenium
import pandas as pd
from selenium import webdriver # Importing selenium webdriver 

# Importing required Exceptions which needs to handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

# %%
driver=webdriver.Chrome(executable_path="C:\\Users\\HP\\chromedriver.exe")

# %%
# Opening the url
driver.get('https://timesofindia.indiatimes.com/archive/year-2020,month-6.cms')

# %%
#creating empty lists
Date=[]
Author=[]
Vertical=[]
Headline=[]
Description=[]

# %%
#creating a list url so that all the urls of date from 1st June to 30th june can be appended
url=[]
for i in driver.find_elements_by_xpath("//div[@id='calenderdiv']/table/tbody/tr[2]/td[2]/a"):
    url.append(i.get_attribute("href"))
for i in driver.find_elements_by_xpath("//div[@id='calenderdiv']/table/tbody/tr[2]/td[3]/a"):
    url.append(i.get_attribute("href"))
for i in driver.find_elements_by_xpath("//div[@id='calenderdiv']/table/tbody/tr[2]/td[4]/a"):
    url.append(i.get_attribute("href"))
for i in driver.find_elements_by_xpath("//div[@id='calenderdiv']/table/tbody/tr[2]/td[5]/a"):
    url.append(i.get_attribute("href"))
for i in driver.find_elements_by_xpath("//div[@id='calenderdiv']/table/tbody/tr[2]/td[6]/a"):
    url.append(i.get_attribute("href"))
for i in driver.find_elements_by_xpath("//div[@id='calenderdiv']/table/tbody/tr[2]/td[7]/a"):
    url.append(i.get_attribute("href"))    
for i in driver.find_elements_by_xpath("//div[@id='calenderdiv']/table/tbody/tr[3]/td/a"):
    url.append(i.get_attribute("href"))
for i in driver.find_elements_by_xpath("//div[@id='calenderdiv']/table/tbody/tr[4]/td/a"):
    url.append(i.get_attribute("href"))
for i in driver.find_elements_by_xpath("//div[@id='calenderdiv']/table/tbody/tr[5]/td/a"):
    url.append(i.get_attribute("href"))
for i in driver.find_elements_by_xpath("//div[@id='calenderdiv']/table/tbody/tr[6]/td[1]/a"):
    url.append(i.get_attribute("href"))
for i in driver.find_elements_by_xpath("//div[@id='calenderdiv']/table/tbody/tr[6]/td[2]/a"):
    url.append(i.get_attribute("href"))  
for i in driver.find_elements_by_xpath("//div[@id='calenderdiv']/table/tbody/tr[6]/td[3]/a"):
    url.append(i.get_attribute("href"))

# %%
url
# Out:
# ['https://timesofindia.indiatimes.com/2020/6/1/archivelist/year-2020,month-6,starttime-43983.cms',
#  'https://timesofindia.indiatimes.com/2020/6/2/archivelist/year-2020,month-6,starttime-43984.cms',
#  'https://timesofindia.indiatimes.com/2020/6/3/archivelist/year-2020,month-6,starttime-43985.cms',
#  'https://timesofindia.indiatimes.com/2020/6/4/archivelist/year-2020,month-6,starttime-43986.cms',
#  'https://timesofindia.indiatimes.com/2020/6/5/archivelist/year-2020,month-6,starttime-43987.cms',
#  'https://timesofindia.indiatimes.com/2020/6/6/archivelist/year-2020,month-6,starttime-43988.cms',
#  'https://timesofindia.indiatimes.com/2020/6/7/archivelist/year-2020,month-6,starttime-43989.cms',
#  'https://timesofindia.indiatimes.com/2020/6/8/archivelist/year-2020,month-6,starttime-43990.cms',
#  'https://timesofindia.indiatimes.com/2020/6/9/archivelist/year-2020,month-6,starttime-43991.cms',
#  'https://timesofindia.indiatimes.com/2020/6/10/archivelist/year-2020,month-6,starttime-43992.cms',
#  'https://timesofindia.indiatimes.com/2020/6/11/archivelist/year-2020,month-6,starttime-43993.cms',
#  'https://timesofindia.indiatimes.com/2020/6/12/archivelist/year-2020,month-6,starttime-43994.cms',
#  'https://timesofindia.indiatimes.com/2020/6/13/archivelist/year-2020,month-6,starttime-43995.cms',
#  'https://timesofindia.indiatimes.com/2020/6/14/archivelist/year-2020,month-6,starttime-43996.cms',
#  'https://timesofindia.indiatimes.com/2020/6/15/archivelist/year-2020,month-6,starttime-43997.cms',
#  'https://timesofindia.indiatimes.com/2020/6/16/archivelist/year-2020,month-6,starttime-43998.cms',
#  'https://timesofindia.indiatimes.com/2020/6/17/archivelist/year-2020,month-6,starttime-43999.cms',
#  'https://timesofindia.indiatimes.com/2020/6/18/archivelist/year-2020,month-6,starttime-44000.cms',
#  'https://timesofindia.indiatimes.com/2020/6/19/archivelist/year-2020,month-6,starttime-44001.cms',
#  'https://timesofindia.indiatimes.com/2020/6/20/archivelist/year-2020,month-6,starttime-44002.cms',
#  'https://timesofindia.indiatimes.com/2020/6/21/archivelist/year-2020,month-6,starttime-44003.cms',
#  'https://timesofindia.indiatimes.com/2020/6/22/archivelist/year-2020,month-6,starttime-44004.cms',
#  'https://timesofindia.indiatimes.com/2020/6/23/archivelist/year-2020,month-6,starttime-44005.cms',
#  'https://timesofindia.indiatimes.com/2020/6/24/archivelist/year-2020,month-6,starttime-44006.cms',
#  'https://timesofindia.indiatimes.com/2020/6/25/archivelist/year-2020,month-6,starttime-44007.cms',
#  'https://timesofindia.indiatimes.com/2020/6/26/archivelist/year-2020,month-6,starttime-44008.cms',
#  'https://timesofindia.indiatimes.com/2020/6/27/archivelist/year-2020,month-6,starttime-44009.cms',
#  'https://timesofindia.indiatimes.com/2020/6/28/archivelist/year-2020,month-6,starttime-44010.cms',
#  'https://timesofindia.indiatimes.com/2020/6/29/archivelist/year-2020,month-6,starttime-44011.cms',
#  'https://timesofindia.indiatimes.com/2020/6/30/archivelist/year-2020,month-6,starttime-44012.cms']

# %%
#opening the first url i.e., 1st June
driver.get(url[0])
URLS1=[] #appending all the urls of the news from 1st december
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS1.append(i.get_attribute("href"))

# %%
#URLS1

# %%
#len(URLS1)

# %%
for i in URLS1[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
Date
# Out:
# ['SUBSCRIBE NOW\nto get the latest news, gossip on your favourite stars & oven-fresh movie reviews from top reviewers right in your inbox.\nSubscribe\nBy subscribing to newsletter, you acknowledge our privacy policy',
#  'Created: Jun 1, 2020, 00:00 IST',
#  'Created: Jun 1, 2020, 00:00 IST',
#  'Created: Jun 1, 2020, 00:00 IST',
#  'Updated: Jun 1, 2020, 11:16 IST',
#  'Created: Jun 1, 2020, 00:01 IST',
#  'SUBSCRIBE NOW\nto get the latest news, gossip on your favourite stars & oven-fresh movie reviews from top reviewers right in your inbox.\nSubscribe\nBy subscribing to newsletter, you acknowledge our privacy policy',
#  'SUBSCRIBE NOW\nto get the latest news, gossip on your favourite stars & oven-fresh movie reviews from top reviewers right in your inbox.\nSubscribe\nBy subscribing to newsletter, you acknowledge our privacy policy',
#  '',
#  'PTI | Jun 1, 2020, 00:31 IST',
#  '-',
#  'SUBSCRIBE NOW\nto get the latest news, gossip on your favourite stars & oven-fresh movie reviews from top reviewers right in your inbox.\nSubscribe\nBy subscribing to newsletter, you acknowledge our privacy policy',
#  '-',
#  '-',
#  '-',
#  '-',
#  'Reuters | Jun 1, 2020, 01:27 IST',
#  '-',
#  '',
#  'TNN | Updated: Jun 1, 2020, 08:22 IST']

# %%
Headline
# Out:
# ['Hackers target Kannada stars’ social media accounts; time to secure yours',
#  'Anarkali Nazar plays a singer in Mohan Kumar Fans',
#  'Magalu Janaki cancelled, TN Seetharam begins work on series about a superstar',
#  'Shruti to play the lead in Aval Appadithan remake?',
#  'WFH Hangover: India struggles to switch back to office mode',
#  'The Arjuna Award nomination will motivate me to work harder: Ankita Raina',
#  'Day Knight actor bags an American film',
#  'I’m super excited to hone my hula hoop skills: Mehr Mahajan',
#  "Apurva Bose's facetime photoshoot by Shafi Shakeer is real fun",
#  'US will consider rejoining WHO if it ends corruption, reliance on China: White House',
#  '-',
#  'When Urvashi was asked to improvise a scene for Varane Avashyamund',
#  '-',
#  '-',
#  '-',
#  '-',
#  'Militants in Burkina Faso kill 35 in separate attacks, govt says',
#  'Prajakta recalls her Dokyala Shot days',
#  'Puri Jagan heaps praise on Mahesh Babu’s Sarkaru Vaari Paata',
#  '3 Pakistan mission staffers caught spying, 2 of them expelled']

# %%
Author
# Out:
# ['Created: Jun 1, 2020, 00:00 IST',
#  'Deepa Soman',
#  'Madhu Daithota',
#  'V Lakshmi',
#  'Suhas Yellapantula, Thinkal Menon and Sidharthan Venkatramesh',
#  'Soumitra Das',
#  'Updated: Jun 1, 2020, 16:10 IST',
#  'Updated: Jun 1, 2020, 00:17 IST',
#  'Updated: Jun 1, 2020, 00:34 IST',
#  '-',
#  '-',
#  'Created: Jun 1, 2020, 00:47 IST',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  'SPONSORED STORIES\nHindustan Talkies Bags a Tiger\nRaftaar to feature in ‘Bhangra Boogie Cup’ Fortnite campaign\nMeet the new talent in Bollywood',
#  'Created: Jun 1, 2020, 01:51 IST',
#  '-']

# %%
Description
# Out:
# ['Presenting: The curious case of the hack of Ashika Ranganath, Manvitha Kamath and Vasishta N Simha’s Instagram accounts WHAT TRANSPIRED\nThe three actors received click bait links claiming copyright infringement, which they responded to and temporarily lost control over their Instagram accounts. While Manvitha and Ashika had a message that appeared to be of Turkish origin on the landing page, the hacker in Vasishta’s case was closer home, Mulbagal in Karnataka, and had been pretending to be the actor to chat with ‘fans’.\nTHE ROAD TO RECOVERY\n\nThe actors sought expert help to retrieve their accounts and changed passwords and other personal log in details. In Ashika’s case, it was even quicker, as she had a two-factor authentication process lined up, which alerted her about some unusual activity.\n\nUPPING SECURITY FEATURES All three have since upped the security settings on their social media accounts with two-factor authentication to prevent future hacking possibilities.\n\nMEANWHILE, CYBER CRIME ON THE RISE, SAYS TOP COP\n\nBengaluru city commissioner of police Bhaskar Rao tells us, “There has been a spike in the rate of cybercrimes since the lockdown. Everyone is indoors, so the scope for physical crime isn’t as much. Instead, there are criminals lurking online. Just as you have locks for the doors and windows to prevent thefts at home, your internet activity needs to be completely secure to allow no one to enter.”\n\n\nHacking of celeb accounts on the rise\n\nActor Dhruva Sarja’s wife Prerana’s Instagram handle has been renamed Instagramcentrecopyight for over a fortnight now. Even actress Pooja Hegde had claimed that her account was hacked, after ‘she’ made an unsavoury comment about a fellow artiste.\n\n\nEXPERTSPEAK\nDo no put your personal information in sources and sites that are likely to be compromised.\nDon’t get lured by contests and give out your information. Be careful about what you share.\nDo not access free Wi-fi unless you are sure of it. Choose to connect through a VPN if you use public Wi-fi for work.\nTry to keep your confidential data encrypted on your devices. Whenever you sell an old laptop or mobile phone, format it and clear all data.\nUse strong passwords and enable 2-factor authentication whenever possible.\nWhen using an email to log on to a social media site, ensure your passwords for both are different. Don’t have similar passwords for your other social media accounts too.',
fforts are being made to track down the informants as well. The agencies are probing whether other staff members from the high commission were also involved in the spying racket.\nA report regarding the interrogation was sent to the MEA. After registering an FIR, the men were sent for a medical examination and then handed over to the high commission.\nSources said Abid Hussain was posted as a visa assistant since December 2018, while Tahir Khan was an upper division clerk who came to India around the same time. Javed Hussain was working as a driver for the past five and a half years.\nIn 2016, Delhi Police had busted another spy ring comprising more than a dozen officials from the Pakistan high commission after they caught a staffer, Mehmood Akhtar, who was retrieving data about BSF deployments along the Indo-Pak border. Following this, 16 staff members from the high commission were expelled after they were found to be obtaining information from different sources. After that, the ISI had been been using its agents posted in Pakistan\'s missions in nei ...

# %%
Vertical
# Out:
# ['Entertainment',
#  'Entertainment',
#  'TV',
#  'Entertainment',
#  'Lifestyle',
#  'Lifestyle',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  '-',
#  '-',
#  'Entertainment',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  'Entertainment',
#  'Entertainment',
#  'India']

# %%
#print(len(Date),len(Description),len(Headline),len(Vertical),len(Author))
# Out:
# 5 5 5 5 5

# %%
driver.get(url[1])
URLS2=[] #appending all the urls of the news from 1st december
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS2.append(i.get_attribute("href"))

# %%
for i in URLS2[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
driver.get(url[2])
URLS3=[] #appending all the urls of the news from 1st december
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS3.append(i.get_attribute("href"))

# %%
for i in URLS3[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
driver.get(url[3])
URLS4=[] #appending all the urls of the news from 1st december
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS4.append(i.get_attribute("href"))

# %%
for i in URLS4[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
Date
# Out:
# ['SUBSCRIBE NOW\nto get the latest news, gossip on your favourite stars & oven-fresh movie reviews from top reviewers right in your inbox.\nSubscribe\nBy subscribing to newsletter, you acknowledge our privacy policy',
#  'Created: Jun 1, 2020, 00:00 IST',
#  'Created: Jun 1, 2020, 00:00 IST',
#  'Created: Jun 1, 2020, 00:00 IST',
#  'Updated: Jun 1, 2020, 11:16 IST',
#  'Created: Jun 1, 2020, 00:01 IST',
#  'SUBSCRIBE NOW\nto get the latest news, gossip on your favourite stars & oven-fresh movie reviews from top reviewers right in your inbox.\nSubscribe\nBy subscribing to newsletter, you acknowledge our privacy policy',
#  'SUBSCRIBE NOW\nto get the latest news, gossip on your favourite stars & oven-fresh movie reviews from top reviewers right in your inbox.\nSubscribe\nBy subscribing to newsletter, you acknowledge our privacy policy',
#  '',
#  'PTI | Jun 1, 2020, 00:31 IST',
#  '-',
#  'SUBSCRIBE NOW\nto get the latest news, gossip on your favourite stars & oven-fresh movie reviews from top reviewers right in your inbox.\nSubscribe\nBy subscribing to newsletter, you acknowledge our privacy policy',
#  '-',
#  '-',
#  '-',
#  '-',
#  'Reuters | Jun 1, 2020, 01:27 IST',
#  '-',
#  '',
#  'TNN | Updated: Jun 1, 2020, 08:22 IST',
#  'Created: Jun 2, 2020, 00:00 IST',
#  'Created: Jun 2, 2020, 00:00 IST',
#  'Created: Jun 2, 2020, 00:00 IST',
#  'Created: Jun 2, 2020, 00:00 IST',
#  'I P Singh | TNN | Jun 2, 2020, 00:06 IST',
#  'Shikha Salaria | TNN | Jun 2, 2020, 00:12 IST',
#  'M Saleem Pandit | TNN | Jun 2, 2020, 00:20 IST',
#  '-',
#  'M Saleem Pandit | TNN | Jun 2, 2020, 00:24 IST',
#  'Sanjay Khajuria | TNN | Jun 2, 2020, 00:26 IST',
#  'Updated: Jun 2, 2020, 00:41 IST',
#  'SUBSCRIBE NOW\nto get the latest news, gossip on your favourite stars & oven-fresh movie reviews from top reviewers right in your inbox.\nSubscribe\nBy subscribing to newsletter, you acknowledge our privacy policy',
#  'SUBSCRIBE NOW\nGet a weekly dose of all the major happenings in the TV world, right in your inbox every Friday.\nSubscribe\nBy subscribing to newsletter, you acknowledge our privacy policy',
#  'PTI | Jun 2, 2020, 00:49 IST',
#  '-',
#  '-',
#  'Created: Jun 2, 2020, 01:00 IST',
#  'Niharika Lal | TNN | Jun 2, 2020, 01:00 IST',
#  '-',
#  '-',
#  'Vinay Lokesh | TNN | Updated: Jun 3, 2020, 09:39 IST',
#  '-',
#  '',
#  'Created: Jun 3, 2020, 00:00 IST',
#  'SUBSCRIBE NOW\nto get the latest news, gossip on your favourite stars & oven-fresh movie reviews from top reviewers right in your inbox.\nSubscribe\nBy subscribing to newsletter, you acknowledge our privacy policy',
#  'Created: Jun 3, 2020, 00:08 IST',
#  'Rajiv Mani | TNN | Updated: Jun 3, 2020, 00:13 IST',
#  'TIMESOFINDIA.COM | Updated: Jun 3, 2020, 00:17 IST',
#  'Rajendra Sharma | TNN | Jun 3, 2020, 00:21 IST',
#  '-',
#  'Shariq Majeed | TNN | Jun 3, 2020, 00:27 IST',
#  'TIMESOFINDIA.COM | Updated: Jun 3, 2020, 09:39 IST',
#  'Debashish Karmakar | TNN | Updated: Jun 3, 2020, 00:30 IST',
#  'Pradeep Thakur | TNN | Updated: Jun 3, 2020, 09:41 IST',
#  'Madan Kumar | TNN | Jun 3, 2020, 00:37 IST',
#  'Ajay Sura | TNN | Jun 3, 2020, 00:50 IST',
#  'Saurabh Sinha | TNN | Jun 3, 2020, 00:51 IST',
#  '-',
#  'Ismat Tahseen | TNN | Updated: Jun 3, 2020, 18:58 IST',
#  '-',
#  'SUBSCRIBE NOW\nFind out about the latest Lifestyle, Fashion & Beauty trends, Relationship tips & the buzz on Health & Food.\nSubscribe\nBy subscribing to newsletter, you acknowledge our privacy policy',
#  'Updated: Jun 4, 2020, 07:35 IST',
#  'Created: Jun 4, 2020, 00:00 IST',
#  'SUBSCRIBE NOW\nto get the latest news, gossip on your favourite stars & oven-fresh movie reviews from top reviewers right in your inbox.\nSubscribe\nBy subscribing to newsletter, you acknowledge our privacy policy',
#  'Manyaekta Gugliani | TNN | Updated: Jun 4, 2020, 14:03 IST',
#  'Manyaekta Gugliani | TNN | Updated: Jun 4, 2020, 14:03 IST',
#  '-',
#  'SUBSCRIBE NOW\nto get the latest news, gossip on your favourite stars & oven-fresh movie reviews from top reviewers right in your inbox.\nSubscribe\nBy subscribing to newsletter, you acknowledge our privacy policy',
#  'SUBSCRIBE NOW\nto get the latest news, gossip on your favourite stars & oven-fresh movie reviews from top reviewers right in your inbox.\nSubscribe\nBy subscribing to newsletter, you acknowledge our privacy policy',
#  'Created: Jun 4, 2020, 00:55 IST',
#  'SUBSCRIBE NOW\nGet a weekly dose of all the major happenings in the TV world, right in your inbox every Friday.\nSubscribe\nBy subscribing to newsletter, you acknowledge our privacy policy',
#  '-',
#  'SUBSCRIBE NOW\nto get the latest news, gossip on your favourite stars & oven-fresh movie reviews from top reviewers right in your inbox.\nSubscribe\nBy subscribing to newsletter, you acknowledge our privacy policy',
#  '-',
#  '-',
#  '-',
#  'TNN | Updated: Jun 4, 2020, 12:40 IST',
#  'Vishwa Mohan | TNN | Updated: Jun 4, 2020, 09:17 IST',
#  'Created: Jun 4, 2020, 01:11 IST',
#  'Anam Ajmal | TNN | Jun 4, 2020, 01:32 IST']

# %%
Headline
# Out:
# ['Hackers target Kannada stars’ social media accounts; time to secure yours',
#  'Anarkali Nazar plays a singer in Mohan Kumar Fans',
#  'Magalu Janaki cancelled, TN Seetharam begins work on series about a superstar',
#  'Shruti to play the lead in Aval Appadithan remake?',
#  'WFH Hangover: India struggles to switch back to office mode',
#  'The Arjuna Award nomination will motivate me to work harder: Ankita Raina',
#  'Day Knight actor bags an American film',
#  'I’m super excited to hone my hula hoop skills: Mehr Mahajan',
#  "Apurva Bose's facetime photoshoot by Shafi Shakeer is real fun",
#  'US will consider rejoining WHO if it ends corruption, reliance on China: White House',
#  '-',
#  'When Urvashi was asked to improvise a scene for Varane Avashyamund',
#  '-',
#  '-',
#  '-',
#  '-',
#  'Militants in Burkina Faso kill 35 in separate attacks, govt says',
#  'Prajakta recalls her Dokyala Shot days',
#  'Puri Jagan heaps praise on Mahesh Babu’s Sarkaru Vaari Paata',
#  '3 Pakistan mission staffers caught spying, 2 of them expelled',
#  'Ladakh, Darjeeling and Madikeri emerge as new shooting hotspots for Kannada filmmakers',
#  'Lingadevaru starts welfare petition for film technicians',
#  'Will the mall experience change in the post-COVID-19 world?',
#  'JK Rowling delights little fans from India for their ‘Ickabog’ artwork',
#  'Arjuna awardee former Punjab police SSP booked for rash driving',
#  'Two massive fires in Noida; 27 tenders, 80 firemen struggle to douse the blaze',
#  'Terror warning to ‘Indians’: Don’t settle in J&K',
#  '-',
#  'Three drug peddlers arrested in Srinagar',
#  'Army foils infiltration bid in Nowshera, kills 3 terrorists',
#  'He had passion for music and josh for life: Music industry remembers Wajid Khan',
#  'Never take your mental breakdowns as personal failures: Gautami Berde',
#  'Post-lockdown rules: Will family scenes on daily soaps shrink in size?',
#  'India may operate special flight from S Africa to bring home stranded citizens',
#  '-',
#  '-',
#  'Siddhant Chaturvedi explores his love for rap and poetry with his first single',
#  'Corona pandemic is changing the way people travel in cabs',
#  '-',
#  '-',
#  'Life has become more tough for differently-abled people: para-swimmer Vishwas KS',
#  "'As long as there is hunger and thirst, F&B industry will exist'",
#  'Covid-19 impact: Fashion brands and retailers ask malls to reduce rent till business returns to normal',
#  'I’m channeling my anxiety into making music: Sid Sriram',
#  'Cyclone Nisarga: Akshay Kumar urges everyone to take necessary precautions shared by the BMC',
#  'Swwapnil Joshi focusses on fitness during lockdown, goes on a detox diet',
#  'TTE-less travel introduced at Prayagraj railway station',
#  'Google starts rolling June 2020 Android security patch for Pixel smartphones',
#  "MP home minister supports replacing 'India' with 'Bharat', says it gives a 'feeling of affinity'",
#  '-',
#  'Seven more Covid-19 cases reported in Ludhiana: DC',
#  'Asus launches new AMD Ryzen-powered TUF-series laptops and Strix desktop computers in India',
#  'Bihar: Two girls attempt suicide, die at hospital',
#  'ED files chargesheet against Chidambaram, son in INX case',
#  'Amit Shah to sound bugle for Bihar assembly polls through virtual rally on June 7',
#  'Haryana issues SOPs for taxis, cabs and autorickshaws',
#  'Cyclone Nisarga impact: Mumbai Airport to handle 19 flights today',
#  '-',
#  'Cycling, the solution to commuting fears during pandemic?',
#  '-',
#  'Is SEX really good for your skin?',
#  'I take cinema very seriously, so I would like to ace each aspect that I want to get into: Manvita Kamath',
#  "Television show 'Vidya' axed",
#  'The unknown, ‘wild’ side of Srinda',
#  'Unique environment conservation campaign in Bareilly',
#  'Unique environment conservation campaign in Bareilly',
#  '-',
#  'Kareena Kapoor Khan is all hearts as her niece Inaaya Naumi Kemmu draws an adorable family tree; view picture',
#  'B-Town actors outraged at the inhuman act that led to the death of a pregnant elephant in Kerala',
#  'Paras Chhabra: I don’t want to go down the regular route of proposing to Mahira. I want everything to happen organically',
#  'Chahatt Khanna pledges to eat only one meal a day to help the needy',
#  '-',
#  'The lockdown has given me the opportunity to do things that had been on my to-do list for a long time: Govind Namdeo',
#  '-',
#  '-',
#  '-',
#  'Punjab: Speculation rife over AAP getting in touch with Navjot Singh Sidhu',
#  'Cabinet clears ordinances to kick in agri reforms, create ‘One India, One Agri-Market’',
#  'Shabana Azmi: Just like other industries, the Hindi film industry also needs support',
#  'Google pulls out ‘Remove China Apps’ over policy violations']

# %%
Vertical
# Out:
# ['Entertainment',
#  'Entertainment',
#  'TV',
#  'Entertainment',
#  'Lifestyle',
#  'Lifestyle',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  '-',
#  '-',
#  'Entertainment',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  'Entertainment',
#  'Entertainment',
#  'India',
#  'Entertainment',
#  'Entertainment',
#  'Lifestyle',
#  'Lifestyle',
#  'City',
#  'City',
#  'India',
#  '-',
#  'India',
#  'India',
#  'Entertainment',
#  'Entertainment',
#  'TV',
#  'India',
#  '-',
#  '-',
#  'Entertainment',
#  'City',
#  '-',
#  '-',
#  'City',
#  'Lifestyle',
#  'Lifestyle',
#  'Entertainment',
#  'Entertainment',
#  'TV',
#  'City',
#  '-',
#  'City',
#  '-',
#  'City',
#  '-',
#  'City',
#  'India',
#  'City',
#  'City',
#  '-',
#  '-',
#  'City',
#  '-',
#  'Lifestyle',
#  'Entertainment',
#  'TV',
#  'Entertainment',
#  'City',
#  '-',
#  'Entertainment',
#  'Entertainment',
#  'Entertainment',
#  'TV',
#  'TV',
#  '-',
#  'Entertainment',
#  '-',
#  '-',
#  '-',
#  'City',
#  'India',
#  'Entertainment',
#  '-']

# %%
Description
# Out:
# ['Presenting: The curious case of the hack of Ashika Ranganath, Manvitha Kamath and Vasishta N Simha’s Instagram accounts WHAT TRANSPIRED\nThe three actors received click bait links claiming copyright infringement, which they responded to and temporarily lost control over their Instagram accounts. While Manvitha and Ashika had a message that appeared to be of Turkish origin on the landing page, the hacker in Vasishta’s case was closer home, Mulbagal in Karnataka, and had been pretending to be the actor to chat with ‘fans’.\nTHE ROAD TO RECOVERY\n\nThe actors sought expert help to retrieve their accounts and changed passwords and other personal log in details. In Ashika’s case, it was even quicker, as she had a two-factor authentication process lined up, which alerted her about some unusual activity.\n\nUPPING SECURITY FEATURES All three have since upped the security settings on their social media accounts with two-factor authentication to prevent future hacking possibilities.\n\nMEANWHILE, CYBER CRIME ON THE RISE, SAYS TOP COP\n\nBengaluru city commissioner of police Bhaskar Rao tells us, “There has been a spike in the rate of cybercrimes since the lockdown. Everyone is indoors, so the scope for physical crime isn’t as much. Instead, there are criminals lurking online. Just as you have locks for the doors and windows to pr
#  'NEW DELHI: Google pulled out the ‘Remove China Apps’ (RCA) application from its Play Store on Tuesday.\nThe software, which claimed to remove apps developed in China from a user’s phone, had gone viral amid a nerve-jangling border stand-off between India and China.\nAccording to analytics firm Sensor Tower, which tracks the number of downloads of popular applications, RCA was downloaded over 4.7 million times between May 27 and June 1. It’s removal created a furore on Wednesday.\nJaipur-based firm OneTouch AppLabs (OTA), who had developed RCA, tweeted, “Dear Friends, Google has suspended our #RemoveChinaApps from google play store. Thank you all for your support in past two weeks.”\nGoogle said the application was removed because it violated the “Privacy, Security and Deception” policies which prohibit any app on the Play Store from “misusing any network, device, or personal data”.']

# %%
Author
# Out:
# ['Created: Jun 1, 2020, 00:00 IST',
#  'Deepa Soman',
#  'Madhu Daithota',
#  'V Lakshmi',
#  'Suhas Yellapantula, Thinkal Menon and Sidharthan Venkatramesh',
#  'Soumitra Das',
#  'Updated: Jun 1, 2020, 16:10 IST',
#  'Updated: Jun 1, 2020, 00:17 IST',
#  'Updated: Jun 1, 2020, 00:34 IST',
#  '-',
#  '-',
#  'Created: Jun 1, 2020, 00:47 IST',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  'SPONSORED STORIES\nHindustan Talkies Bags a Tiger\nRaftaar to feature in ‘Bhangra Boogie Cup’ Fortnite campaign\nMeet the new talent in Bollywood',
#  'Created: Jun 1, 2020, 01:51 IST',
#  '-',
#  'Sunayana Suresh',
#  'Vinay Lokesh',
#  'V Lakshmi',
#  'Sruthi Raman',
#  'I P Singh',
#  'Shikha Salaria',
#  'M Saleem Pandit',
#  '-',
#  'M Saleem Pandit',
#  'Sanjay Khajuria',
#  'Tanvi Trivedi, Debarati S Sen',
#  'SPONSORED STORIES\nHindustan Talkies Bags a Tiger\nRaftaar to feature in ‘Bhangra Boogie Cup’ Fortnite campaign\nMeet the new talent in Bollywood',
#  'Created: Jun 2, 2020, 00:48 IST',
#  '-',
#  '-',
#  '-',
#  'Rachana Dubey',
#  'Niharika Lal',
#  '-',
#  '-',
#  'Vinay Lokesh',
#  'Created: Jun 3, 2020, 00:00 IST',
#  'Created: Jun 3, 2020, 00:00 IST',
#  'Sharanya CR',
#  'Created: Jun 3, 2020, 00:07 IST',
#  'Neha Maheshwri',
#  'Rajiv Mani',
#  '-',
#  'Rajendra Sharma',
#  '-',
#  'Shariq Majeed',
#  '-',
#  'Debashish Karmakar',
#  'Pradeep Thakur',
#  'Madan Kumar',
#  'Ajay Sura',
#  'Saurabh Sinha',
#  '-',
#  'Ismat Tahseen',
#  '-',
#  'Created: Jun 4, 2020, 00:00 IST',
#  'Sandra Marina Fernandes',
#  'Tanvi Trivedi',
#  'Created: Jun 4, 2020, 00:04 IST',
#  'Manyaekta Gugliani',
#  'Manyaekta Gugliani',
#  'Rachana Dubey',
#  'Created: Jun 4, 2020, 00:25 IST',
#  'SPONSORED STORIES\nHindustan Talkies Bags a Tiger\nRaftaar to feature in ‘Bhangra Boogie Cup’ Fortnite campaign\nMeet the new talent in Bollywood',
#  'Neha Maheshwri',
#  'Created: Jun 4, 2020, 00:59 IST',
#  '-',
#  'Created: Jun 4, 2020, 01:00 IST',
#  '-',
#  '-',
#  '-',
#  '-',
#  'Vishwa Mohan',
#  'Debarati S Sen',
#  'Anam Ajmal']

# %%
driver.get(url[4])
URLS5=[] #appending all the urls of the news from 1st december
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS5.append(i.get_attribute("href"))

# %%
for i in URLS5[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
driver.get(url[5])
URLS6=[] #appending all the urls of the news from 1st december
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS6.append(i.get_attribute("href"))

# %%
for i in URLS6[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
driver.get(url[6])
URLS7=[] #appending all the urls of the news from 1st december
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS7.append(i.get_attribute("href"))

# %%
for i in URLS7[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
driver.get(url[7])
URLS8=[] #appending all the urls of the news from 1st december
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS8.append(i.get_attribute("href"))

# %%
for i in URLS8[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
driver.get(url[8])
URLS9=[] #appending all the urls of the news from 1st december
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS9.append(i.get_attribute("href"))

# %%
for i in URLS9[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
driver.get(url[9])
URLS10=[] #appending all the urls of the news from 1st december
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS10.append(i.get_attribute("href"))

# %%
for i in URLS10[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
driver.get(url[10])
URLS11=[] #appending all the urls of the news from 1st december
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS11.append(i.get_attribute("href"))

# %%
for i in URLS11[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
driver.get(url[11])
URLS12=[] #appending all the urls of the news from 1st december
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS12.append(i.get_attribute("href"))

# %%
for i in URLS12[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
driver.get(url[12])
URLS13=[] #appending all the urls of the news from 1st december
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS13.append(i.get_attribute("href"))

# %%
for i in URLS13[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
driver.get(url[13])
URLS14=[] #appending all the urls of the news from 1st december
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS14.append(i.get_attribute("href"))

# %%
for i in URLS14[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
driver.get(url[14])
URLS15=[] #appending all the urls of the news from 1st december
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS15.append(i.get_attribute("href"))

# %%
for i in URLS15[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
driver.get(url[15])
URLS16=[] #appending all the urls of the news from 1st december
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS16.append(i.get_attribute("href"))

# %%
for i in URLS16[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
driver.get(url[16])
URLS17=[] #appending all the urls of the news from 1st december
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS17.append(i.get_attribute("href"))

# %%
for i in URLS17[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
driver.get(url[17])
URLS18=[] #appending all the urls of the news from 1st december
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS18.append(i.get_attribute("href"))

# %%
for i in URLS18[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
driver.get(url[18])
URLS19=[] #appending all the urls of the news from 1st december
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS19.append(i.get_attribute("href"))

# %%
for i in URLS19[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
driver.get(url[19])
URLS20=[] #appending all the urls of the news from 1st december
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS20.append(i.get_attribute("href"))

# %%
for i in URLS20[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
driver.get(url[20])
URLS21=[] #appending all the urls of the news from 1st december
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS21.append(i.get_attribute("href"))

# %%
for i in URLS21[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
driver.get(url[21])
URLS22=[] #appending all the urls of the news from 1st december
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS22.append(i.get_attribute("href"))

# %%
for i in URLS22[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
driver.get(url[22])
URLS23=[] #appending all the urls of the news from 1st december
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS23.append(i.get_attribute("href"))

# %%
for i in URLS23[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
driver.get(url[23])
URLS24=[] #appending all the urls of the news from 1st december
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS24.append(i.get_attribute("href"))

# %%
for i in URLS24[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
driver.get(url[24])
URLS25=[] #appending all the urls of the news from 1st december
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS25.append(i.get_attribute("href"))

# %%
for i in URLS25[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
driver.get(url[25])
URLS26=[] #appending all the urls of the news from 1st december
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS26.append(i.get_attribute("href"))

# %%
for i in URLS26[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
driver.get(url[26])
URLS27=[] #appending all the urls of the news from 1st december
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS27.append(i.get_attribute("href"))

# %%
for i in URLS27[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
driver.get(url[27])
URLS28=[] #appending all the urls of the news from 1st december
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS28.append(i.get_attribute("href"))

# %%
for i in URLS28[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
driver.get(url[28])
URLS29=[] #appending all the urls of the news from 1st december
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS29.append(i.get_attribute("href"))

# %%
for i in URLS29[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
driver.get(url[29])
URLS30=[] #appending all the urls of the news from 1st december
for i in driver.find_elements_by_xpath("//div[@style='font-family:arial ;font-size:12;font-weight:bold; color: #006699']/table/tbody/tr[2]/td/span/a"):
    URLS30.append(i.get_attribute("href"))

# %%
for i in URLS30[0:20]:
    driver.get(i)
    try:
        date=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[3]").text
        Date.append(date)
    except NoSuchElementException:
        try:
            date1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div").text
            Date.append(date1)
        except NoSuchElementException: 
            Date.append('-')
            
    try:
        des=driver.find_element_by_xpath("//div[@class='article_content clearfix']/arttextxml/div").text
        Description.append(des)
    except NoSuchElementException:
        try:
            des1=driver.find_element_by_xpath("//div[@class='_1_Akb clearfix  ']/div").text
            Description.append(des1)
        except NoSuchElementException:   
            Description.append('-')
    
    try:
        head=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/h1").text
        Headline.append(head)
    except NoSuchElementException:
        try:
            head1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/h1").text
            Headline.append(head1)
        except NoSuchElementException:   
            Headline.append('-')
    
    try:
        ver=driver.find_element_by_xpath("//div[@class='fix_wrap_md clearfix']/div/div/ol/li[2]/a/span").text
        Vertical.append(ver)
    except NoSuchElementException:
        try:
            ver1=driver.find_element_by_xpath("//li[@class='_8aEAx   K-f4t']/a").text
            Vertical.append(ver1)
        except NoSuchElementException:   
            Vertical.append('-')
    
    try:
        aut=driver.find_element_by_xpath("//div[@class='videos_player_md main_dpygrid']/div/div[2]/div[2]").text
        Author.append(aut)
    except NoSuchElementException:
        try:
            aut1=driver.find_element_by_xpath("//div[@class='_3lvqr clearfix']/div[2]/div/div/span/a").text
            Author.append(aut1)
        except NoSuchElementException:  
            Author.append('-')

# %%
print(len(Date),len(Description),len(Headline),len(Vertical),len(Author))
# Out:
# 600 600 600 600 600

# %%
#creating a dataframe
import pandas as pd
News=pd.DataFrame({})
News['Date']=Date
News['Author']=Author
News['Vertical']=Vertical
News['Headline']=Headline
News['Description']=Description
News
# Out:
#                                                   Date  \
# 0    SUBSCRIBE NOW\nto get the latest news, gossip ...
# 1                      Created: Jun 1, 2020, 00:00 IST
# 2                      Created: Jun 1, 2020, 00:00 IST
# 3                      Created: Jun 1, 2020, 00:00 IST
# 4                      Updated: Jun 1, 2020, 11:16 IST
# ..                                                 ...
# 595  SUBSCRIBE NOW\nto get the latest news, gossip ...
# 596             TNN | Updated: Jun 30, 2020, 10:15 IST
# 597  Bharti Jain | TNN | Updated: Jun 30, 2020, 08:...
# 598             TNN | Updated: Jun 30, 2020, 08:16 IST
# 599                                                  -
#
#                                                 Author       Vertical  \
# 0                      Created: Jun 1, 2020, 00:00 IST  Entertainment
# 1                                          Deepa Soman  Entertainment
# 2                                       Madhu Daithota             TV
# 3                                            V Lakshmi  Entertainment
# 4    Suhas Yellapantula, Thinkal Menon and Sidharth...      Lifestyle
# ..                                                 ...            ...
# 595                   Updated: Jun 30, 2020, 10:53 IST  Entertainment
# 596                                                  -          India
# 597                                        Bharti Jain          India
# 598                                                  -           City
# 599                   Created: Jun 30, 2020, 02:54 IST  Entertainment
#
#                                               Headline  \
# 0    Hackers target Kannada stars’ social media acc...
# 1    Anarkali Nazar plays a singer in Mohan Kumar Fans
# 2    Magalu Janaki cancelled, TN Seetharam begins w...
# 3    Shruti to play the lead in Aval Appadithan rem...
# 4    WFH Hangover: India struggles to switch back t...
# ..                                                 ...
# 595          #FACTCHECK: The Sushant Singh Rajput case
# 596  Sharp Covid spike in south; 18,800+ new cases ...
# 597  Unlock 2.0: Pace of unlocking slows as new cas...
# 598  Tamil Nadu custodial deaths: CCTV footage show...
# 599  Sushmita Sen shares a throwback picture with d...
#
#                                            Description
# 0    Presenting: The curious case of the hack of As...
# 1    Director Jis Joy’s next venture Mohan Kumar Fa...
# 2    In the two months of lockdown, many tele-seria...
# 3    Director Badri Venkatesh is planning a remake ...
# 4    As we step into June 1, today, the reality tha...
# ..                                                 ...
# 595  It’s been two weeks, but the speculations refu...
# 596  NEW DELHI: New Covid-19 cases dipped for the s...
# 597  NEW DELHI: In an indication that the Covid sit...
# 598  TUTICORIN: CCTV footage released by traders in...
# 599  Sushmita Sen is quite active on social media a...
#
# [600 rows x 5 columns]

# %%
#Saving our dataframe into csv file
News.to_csv('June_News_2020.csv', index = False)
